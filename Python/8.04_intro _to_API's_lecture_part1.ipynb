# %%
import random
student_list = ['sybille',
                'mubarik',
                'polly',
                'dina',
                'alen',
                'lorenz',
                'christoph',
                'chuk',
                'marcus',
                'nadine',
                'aleksej',
                'nico',
                'jose',
                'sebastian',
                'silja',
                'dennis',
                'manuel',
                'raffaele',
                'brett',
                'alice',
                'hamid',
                'oliver',
                'arabella',
               ]

# %%
random.choice(student_list)
# Out:
# 'alen'

# %%
ls
# Out:
# "8.04_intro _to_API's_lecture.ipynb"   gnod_clustering.jpg
#  8.04_intro_to_APIs.pptx               img_htmltree.gif
#  car.jpg                               ipynb/
#  gnod_1st_iteration.jpg                lesson.md
#  gnod_1st_prototype.jpg                phone.jpg
#  gnod_2nd_iteration.jpg                restaurant.jpg
#  gnod_2nd_prototype.jpg                what-is-api.jpg
#  gnod_cluster_algorithm.jpg

# %%
display(Image(filename='gnod_1st_iteration.jpg'))

# %%
display(Image(filename='gnod_2nd_iteration.jpg'))

# %%
from IPython.display import display, Image
display(Image(filename='phone.jpg', width=500))
display(Image(filename='car.jpg', width=500))
#display(Image(filename='restaurant.jpg', width=500))

# %%
display(Image(filename='restaurant.jpg', width=500))

# %%
display(Image(filename='phone.jpg', width=500))

# %%
a = "Hello World"

# %%
a
# Out:
# 'Hello World'

# %%
dir(a)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %% [markdown]
# ## Why do we use APIs

# %% [markdown]
# * data change quickly, API's can give us up to date information
# * You just want a piece of all your data
# * repeated computation involved
#
# When do we need APIs: when we need **Automation**, **Efficiency** and **Adaptation**

# %% [markdown]
# REST (**RE**presentation **S**tate **T**ransfer), 6 constraints which make an API a RESTful API

# %%
import requests

google = requests.get("https://developers.google.com")
print("Google: ", google.status_code)

nba = requests.get("https://api.sportsdata.io/api/nba/fantasy/json/CurrentSeason")
print("NBA: ", nba.status_code)

rotten_tomato = requests.get("http://api.rottentomatoes.com/api/public/v1.0/lists/movies/box_office.json")
print("Rotten Tomatoes: ", rotten_tomato.status_code)
# Out:
# Google:  200
# NBA:  401
# Rotten Tomatoes:  403

# %% [markdown]
# * `200`: Everything went ok
# * `301`: The server is redirecting you to a different endpoint
# * `400`: The server thinks you mad a bad request. You're not sending the right data for a request
# * `401`: You're not properly authenticated
# * `403`: Resource you're trying to access is forbidden
# * `404`: Resource does not exist
# * `503`: The server can't handle the request

# %%
print(google.text)
# Out:
# <!doctype html>
# <html
#       lang="en"
#       dir="ltr">
#   <head>
#
#
#
#
#     <meta name="google-signin-client-id" content="721724668570-nbkv1cfusk7kk4eni4pjvepaus73b13t.apps.googleusercontent.com">
#     <meta name="google-signin-scope"
#           content="profile email https://www.googleapis.com/auth/developerprofiles https://www.googleapis.com/auth/developerprofiles.award">
#     <meta property="og:site_name" content="Google Developers">
#     <meta property="og:type" content="website">
#
#
#
#       <meta name="theme-color" content="#ffffff">
#
#
#     <meta charset="utf-8">
#     <meta content="IE=Edge" http-equiv="X-UA-Compatible">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#     <link rel="manifest" href="/_pwa/developers/manifest.json"
#           crossorigin="use-credentials">
#     <link rel="preconnect" href="//www.gstatic.com" crossorigin>
#     <link rel="preconnect" href="//fonts.gstatic.com" crossorigin>
# ...

# %%
google.json()
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-24-2f0f443f32b6> in <module>
# ----> 1 google.json()
#
# ~/anaconda3/envs/ironhack/lib/python3.8/site-packages/requests/models.py in json(self, **kwargs)
#     898                     # used.
#     899                     pass
# --> 900         return complexjson.loads(self.text, **kwargs)
#     901
#     902     @property
#
# ~/anaconda3/envs/ironhack/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# ...

# %%
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/autosuggest/v1.0/UK/GBP/en-GB/"
params = {"query":"Tokyo"}

headers = {'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
           'x-rapidapi-key': "722ca20cc9mshaa25a4e86219777p1b4804jsn37bafcc1144b",
          }

response = requests.get(url, headers = headers, params = params)

response.json()
# Out:
# {'Places': [{'PlaceId': 'TYOA-sky',
#    'PlaceName': 'Tokyo',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'NRT-sky',
#    'PlaceName': 'Tokyo Narita',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'HND-sky',
#    'PlaceName': 'Tokyo Haneda',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'TYOA-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'TJH-sky',
#    'PlaceName': 'Toyooka',
#    'CountryId': 'JP-sky',
#    'RegionId': '',
#    'CityId': 'JTJH-sky',
#    'CountryName': 'Japan'},
#   {'PlaceId': 'OOK-sky',
#    'PlaceName': 'Toksook Bay',
#    'CountryId': 'US-sky',
#    'RegionId': 'AK',
#    'CityId': 'OOKA-sky',
#    'CountryName': 'United States'},
#   {'PlaceId': 'TKZ-sky',
#    'PlaceName': 'Tokoroa',
#    'CountryId': 'NZ-sky',
#    'RegionId': '',
#    'CityId': 'TKZN-sky',
# ...

# %%
url = "https://skyscanner-skyscanner-flight-search-v1.p.rapidapi.com/apiservices/browsequotes/v1.0/US/USD/en-US/SFO-sky/NYCA-sky/2021-02-23"

params = {"inboundpartialdate":"2021-02-23"}

headers = {
    'x-rapidapi-host': "skyscanner-skyscanner-flight-search-v1.p.rapidapi.com",
    'x-rapidapi-key': "722ca20cc9mshaa25a4e86219777p1b4804jsn37bafcc1144b"}

response = requests.get(url, headers=headers, params=params)

response.json()
# Out:
# {'Quotes': [{'QuoteId': 1,
#    'MinPrice': 168,
#    'Direct': True,
#    'OutboundLeg': {'CarrierIds': [851],
#     'OriginId': 81727,
#     'DestinationId': 60987,
#     'DepartureDate': '2021-02-23T00:00:00'},
#    'QuoteDateTime': '2021-02-19T18:53:00'}],
#  'Carriers': [{'CarrierId': 851, 'Name': 'Alaska Airlines'}],
#  'Places': [{'Name': 'New York John F. Kennedy',
#    'Type': 'Station',
#    'PlaceId': 60987,
#    'IataCode': 'JFK',
#    'SkyscannerCode': 'JFK',
#    'CityName': 'New York',
#    'CityId': 'NYCA',
#    'CountryName': 'United States'},
#   {'Name': 'San Francisco International',
#    'Type': 'Station',
#    'PlaceId': 81727,
#    'IataCode': 'SFO',
#    'SkyscannerCode': 'SFO',
#    'CityName': 'San Francisco',
#    'CityId': 'SFOA',
#    'CountryName': 'United States'}],
#  'Currencies': [{'Code': 'USD',
#    'Symbol': '$',
#    'ThousandsSeparator': ',',
#    'DecimalSeparator': '.',
#    'SymbolOnLeft': True,
#    'SpaceBetweenAmountAndSymbol': False,
# ...
