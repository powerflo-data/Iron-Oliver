# %%
import re
import pandas as pd

# %%
# %run ../Iron_Oliver.ipynb

# %%
text = """
Aeromexico 800 - 237 - 6639
Air Canada 888- 247-2262
Air Canada Rouge 888-247-2262
Air Creebec 800-567-6567
Air Inuit 800-361-2965
Air North 800-661-0407
Air Tindi 888-545-6794"""

# %%
#1)
pattern = '\d+-\d+-\d+'

# %%
pattern2 = '\d+\'

# %%
print(re.findall(pattern,text))
# Out:
# ['888-247-2262', '800-567-6567', '800-361-2965', '800-661-0407', '888-545-6794']

# %%
#2)
text = '''TKerraPower, A nuclear-energy company founded by Bill Gates,
        is unlikely to follow through on building a demonstration reactor in China,
        due largely to the Trump administration�s crackdown on the country'''

# %%
pattern =  '[A-Z][a-z]+ ?[A-Z][a-z]+'
pattern2 = '[A-Z][a-z]+'

# %%
print(re.findall(pattern+ '|' + pattern2,text))
# Out:
# ['KerraPower', 'Bill Gates', 'China', 'Trump']

# %%
# Activity 2)
# 1)
data = pd.read_csv('Unit4.csv')

# %%
domain_categories = {"U" : "Urban", "C" : "City", "S" : "Suburban", "T" : "Town", "R" :  "Rural"}

# %%
data['DOMAIN'].value_counts()
# Out:
# Suburban    20737
# Rural       18863
# City        18683
# Town        18521
# Urban       11589
# Name: DOMAIN, dtype: int64

# %%
type(list(domain_categories.keys()))
# Out:
# list

# %%
def domain_clean(data):
    if data[0] in list(domain_categories.keys()):
        return domain_categories[data[0]]
    else:
        return float("nan")

# %%
data['DOMAIN'] = list(map(domain_clean,data['DOMAIN']))

# %%
plot_count_discrete_vals_from_df(pd.DataFrame(data['DOMAIN']))

# %%
data['DOMAIN'].fillna('Suburban')
# Out:
# 0            Town
# 1        Suburban
# 2           Rural
# 3           Rural
# 4        Suburban
#            ...
# 90564    Suburban
# 90565        City
# 90566        City
# 90567        City
# 90568        City
# Name: DOMAIN, Length: 90569, dtype: object

# %%
data['DOMAIN'].value_counts()
# Out:
# Suburban    20737
# Rural       18863
# City        18683
# Town        18521
# Urban       11589
# Name: DOMAIN, dtype: int64

# %%
# Activity 3)
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

# %%
#data_corr = data.corr()
#data.dtypes

# %%
corr_matrix=data.corr(method='pearson')
fig, ax = plt.subplots(figsize=(20, 16))
ax = sns.heatmap(corr_matrix, annot=True)
plt.show()

# %%
#Generate regression plots for highly correlated variables
sns.regplot('NUMPROM','CARDPROM', data=data)
plt.show()
sns.regplot('NUMPROM','NGIFTALL', data=data)
# Out:
# C:\Users\kegel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kegel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NUMPROM', ylabel='NGIFTALL'>

# %%
#Generate regression plots for highly correlated variables
sns.regplot('HV1','HV2', data=data)
plt.show()
sns.regplot('IC1','IC2', data=data)
# Out:
# C:\Users\kegel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\kegel\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='IC1', ylabel='IC2'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
# print(r2_score(data['IC1'],data['IC2']))
# print(r2_score(data['HV1'],data['HV2']))
# print(r2_score(data['NUMPROM'],data['CARDPROM']))
# print(r2_score(data['NUMPROM'],data['NGIFTALL']))
# Out:
# 0.8083227754804095
# 0.9808269286669431
# -0.9645836318521919
# -2.190380606881033

# %%
model = LinearRegression().fit(data[['IC1']], data[['IC2']])
print(model.score(data[['IC1']], data[['IC2']]))

model = LinearRegression().fit(data_corr[['NUMPROM']], data_corr[['CARDPROM']])
print(model.score(data_corr[['NUMPROM']], data_corr[['CARDPROM']]))
# Out:
# 0.9047338877534138
# 0.9839867776382171

# %%
# Activity 4)
# VIF considers the correlation between all other independat variables, whether correlation Matrix
