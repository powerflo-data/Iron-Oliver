# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## MTV not working (due to show more content issue)

# %%
url = "http://www.mtv.de/charts/c6mc86/single-top-100"
response = requests.get(url)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.render()")
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-40-b30555fc9da2> in <module>
# ----> 1 soup = BeautifulSoup(response.content, "html.render()")
#
# ~\anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     241             builder_class = builder_registry.lookup(*features)
#     242             if builder_class is None:
# --> 243                 raise FeatureNotFound(
#     244                     "Couldn't find a tree builder with the features you "
#     245                     "requested: %s. Do you need to install a parser library?"
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html.render(). Do you need to install a parser library?

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js">
#  <head>
#   <!-- Dynamically generated headers -->
#   <title>
#    Offizielle Single Top 100 - Musik Charts | MTV Germany
#   </title>
#   <meta content="Bleibt up to date und seht als erstes die offiziellen deutschen Charts. Wir bieten euch alles zu den aktuellen Charts: Top 100 Single Charts, Top 100 Album Charts, Hip Hop Charts, und viele mehr." name="description"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <script type="text/javascript">
# ...

# %% [markdown]
# ## Testing

# %%
#selecting Title 
soup.select("div.chartItemsBox > div.chartItemTitle > div.videoTitle")[0].get_text()
# Out:
# 'Wellerman'

# %%
#selecting Artist 
soup.select("div.chartItemsBox > div.chartItemTitle > a > span")[0].get_text()
# Out:
# 'Nathan Evans'

# %%
#selecting Rank 
soup.select("div.chartItemsBox > div.positionBox > div.currentPos")[0].get_text()
# Out:
# '1'

# %%
element = soup.select("div.chartItemsBox")

# %%
element[1].select("div.chartItemTitle > div.videoTitle")[0].get_text()
# Out:
# 'Ohne dich'

# %% [markdown]
# ## Gathering Top 100

# %%
len(soup.select("div.chartItemsBox"))
# Out:
# 20

# %%
li_title = []
li_artists = []
li_ranks = []

for element in range(len(soup.select("div.chartItemsBox"))):
    element[1].select("div.chartItemTitle > div.videoTitle")[0].get_text()
