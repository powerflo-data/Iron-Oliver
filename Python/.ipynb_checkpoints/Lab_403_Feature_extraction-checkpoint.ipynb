# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
# %run ../Iron_Oliver.ipynb

# %%
data = pd.read_csv('Lab401.csv')

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Response', 'Coverage',
#        'Education', 'Effective To Date', 'EmploymentStatus', 'Gender',
#        'Income', 'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Number of Open Complaints', 'Number of Policies', 'Policy Type',
#        'Policy', 'Renew Offer Type', 'Sales Channel', 'Total Claim Amount',
#        'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
categoricals = data.select_dtypes(np.object)

# %%
categoricals.isna().sum()
# Out:
# Customer             0
# State                0
# Response             0
# Coverage             0
# Education            0
# Effective To Date    0
# EmploymentStatus     0
# Gender               0
# Location Code        0
# Marital Status       0
# Policy Type          0
# Policy               0
# Renew Offer Type     0
# Sales Channel        0
# Vehicle Class        0
# Vehicle Size         0
# dtype: int64

# %%
plot_count_discrete_vals_from_df(categoricals)
#From the plots we can see:
# Disbalance in the coverage column
# few values for doctor/master in education
# minority policy values can be replaced by other to reduce features maybe
# same goes for vehicle class

# %%
pd.concat([categoricals,data['Total Claim Amount']], axis=1).head(5)
# Out:
#   Customer       State Response  Coverage Education Effective To Date  \
# 0  BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1  QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2  AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3  WW63253  California       No     Basic  Bachelor           1/20/11
# 4  HB64268  Washington       No     Basic  Bachelor            2/3/11
#
#   EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# 0         Employed      F      Suburban        Married  Corporate Auto
# 1       Unemployed      F      Suburban         Single   Personal Auto
# 2         Employed      F      Suburban        Married   Personal Auto
# 3       Unemployed      M      Suburban        Married  Corporate Auto
# 4         Employed      M         Rural         Single   Personal Auto
#
#          Policy Renew Offer Type Sales Channel  Vehicle Class Vehicle Size  \
# ...

# %%
categoricals.columns
# Out:
# Index(['Customer', 'State', 'Response', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Location Code',
#        'Marital Status', 'Policy Type', 'Policy', 'Renew Offer Type',
#        'Sales Channel', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
#figuring out redundant columns
# probably policy type can be dropped, since it hast no hugh impact onto the total claim amount 
# based on linear assumption
plot_bar_Ystring_discrete_vals_from_df(pd.concat([categoricals[['Gender','Vehicle Class','Policy Type']],data['Total Claim Amount']], axis=1),'Total Claim Amount')

# %%
# Plot time variable. Can you extract something from it?
# has no real impact on the total claim amount, so we might can drop it
plot_bar_Ystring_discrete_vals_from_df(pd.concat([categoricals['Effective To Date'],data['Total Claim Amount']], axis=1),'Total Claim Amount')

# %%
plot_count_discrete_vals_from_df(pd.DataFrame(categoricals['Effective To Date']))
