# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn.linear_model import LinearRegression

# %%
# %run ../Iron_Oliver.ipynb

# %%
data = pd.read_csv('Lab401.csv')

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income Location Code  \
# 0           2/24/11         Employed      F   56274      Suburban
# 1           1/31/11       Unemployed      F       0      Suburban
# 2           2/19/11         Employed      F   48767      Suburban
# 3           1/20/11       Unemployed      M       0      Suburban
# 4            2/3/11         Employed      M   43836         Rural
#
#   Marital Status  Monthly Premium Auto  Months Since Last Claim  \
# ...

# %%
data_test = pd.read_csv('Lab401.csv')
continuous_df = get_continous_cols_from_df(data_test,10)
discrete_df = get_discrete_cols_from_df(data_test,10)
cat_df = get_cat_cols_from_df(data_test,10)

# %%
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
def remove_outliers_from_df(data,name,fac):
    iqr = np.percentile(data[name],75) - np.percentile(data[name],25)
    upper_limit = np.percentile(data[name],75) + fac*iqr
    lower_limit = np.percentile(data[name],25) - fac*iqr
    data = data[(data[name]>lower_limit) & (data[name]<upper_limit)]
    return data

# %%
# plotting discrete vals:
plot_count_discrete_vals_from_df(discrete_df)

# %%
plot_bar_Ystring_discrete_vals_from_df(data_test[['Monthly Premium Auto','Education','Response','Gender', 'Number of Open Complaints','Number of Policies','Total Claim Amount']],'Total Claim Amount')

# %%
plot_bar_Ystring_discrete_vals_from_df(data[['Effective To Date','Customer','Total Claim Amount']],'Total Claim Amount')

# %%
cat_df = cat_df.drop(['Customer', 'Effective To Date'], axis = 1)

# %%
#plotting cat values:
plot_count_discrete_vals_from_df(cat_df)

# %%
plot_dist_continue_vals_from_df(continuous_df)

# %%
continuous_df = remove_outliers_from_df(continuous_df,'Total Claim Amount',3)

# %%
sum(continuous_df['Total Claim Amount']>1500)/len(continuous_df)*100
# Out:
# 0.722574994525947

# %%
data.shape
# Out:
# (9134, 24)

# %%
continuous_df.shape
# Out:
# (9019, 6)

# %%
continuous_df = remove_outliers_from_df(continuous_df,'Customer Lifetime Value',3)

# %%
continuous_df.shape
# Out:
# (8651, 6)

# %%
data = data.drop(['Number of Open Complaints', 'Number of Policies', 'Customer','Response'] , axis = 1)

# %%
def clean_education(x):
    list = ['Master', 'Bachelor']
    if x in list:
        return 'College'
    else:
        return x

# %%
data['Education'].value_counts()
# Out:
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: Education, dtype: int64

# %%
data['Education'] = list(map(clean_education,data['Education']))

# %%
data['Education'].value_counts()
# Out:
# College                 6170
# High School or Below    2622
# Doctor                   342
# Name: Education, dtype: int64

# %%
data.shape
# Out:
# (9134, 20)

# %%
data = remove_outliers_from_df(data,'Total Claim Amount',3)

# %%
data.shape
# Out:
# (9019, 20)

# %%
data = remove_outliers_from_df(data,'Customer Lifetime Value',3)

# %%
data.shape
# Out:
# (8651, 20)

# %%
data.columns
# Out:
# Index(['State', 'Customer Lifetime Value', 'Coverage', 'Education',
#        'Effective To Date', 'EmploymentStatus', 'Gender', 'Income',
#        'Location Code', 'Marital Status', 'Monthly Premium Auto',
#        'Months Since Last Claim', 'Months Since Policy Inception',
#        'Policy Type', 'Policy', 'Renew Offer Type', 'Sales Channel',
#        'Total Claim Amount', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
data_copy = data.copy()

# %%
data_copy.dtypes
# Out:
# State                             object
# Customer Lifetime Value          float64
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# Vehicle Size                      object
# dtype: object

# %%
data['Effective To Date'].dtype
# Out:
# dtype('O')

# %%
data['Effective To Date']
# Out:
# 0       2/24/11
# 1       1/31/11
# 2       2/19/11
# 3       1/20/11
# 4        2/3/11
#          ...
# 9129    2/10/11
# 9130    2/12/11
# 9131     2/6/11
# 9132     2/3/11
# 9133    2/14/11
# Name: Effective To Date, Length: 8651, dtype: object

# %%
data_copy['Effective To Date'] = pd.to_datetime(data_copy['Effective To Date'], format="%m/%d/%y")

# %%
data_copy.dtypes
# Out:
# State                                    object
# Customer Lifetime Value                 float64
# Coverage                                 object
# Education                                object
# Effective To Date                datetime64[ns]
# EmploymentStatus                         object
# Gender                                   object
# Income                                    int64
# Location Code                            object
# Marital Status                           object
# Monthly Premium Auto                      int64
# Months Since Last Claim                   int64
# Months Since Policy Inception             int64
# Policy Type                              object
# Policy                                   object
# Renew Offer Type                         object
# Sales Channel                            object
# Total Claim Amount                      float64
# Vehicle Class                            object
# Vehicle Size                             object
# ...

# %%
X_num = data_copy.select_dtypes(np.number)

# %%
X_cat = data_copy.select_dtypes(np.object)

# %%
X_num.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  Total Claim Amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879

# %%
Y = X_num['Total Claim Amount']

# %%
X_num = X_num.drop('Total Claim Amount', axis = 1)

# %%
plot_dist_continue_vals_from_df(X_num)

# %%
#X_num['Monthly Premium Auto_log'] = list(map(log_transform_clean,X_num['Monthly Premium Auto']))

# %%
# xt, lmbda = stats.boxcox(X_num['Monthly Premium Auto'])
# X_num['Monthly Premium Auto_boxcox'] = xt

# %%
from sklearn.preprocessing import StandardScaler
transformer = StandardScaler().fit(X_num)
x_standardized = transformer.transform(X_num)
#print(x_standardized.shape)

# %%
from sklearn.preprocessing import Normalizer
transformer = Normalizer().fit(X_num)
x_normalized = transformer.transform(X_num)
#print(x_normalized.shape)
#pd.DataFrame(x_normalized)

# %%
# concering the normalization, we choose standardscaler, as the results look more 
# like normal distributed values

# %%
for i in range(x_standardized.shape[1]):
    sns.distplot(x_standardized[:,i])
    plt.show()

# %%
# for i in range(x_normalized.shape[1]):
#     sns.distplot(x_normalized[:,i])
#     plt.show()

# %%
X_cat['EmploymentStatus'].unique()
# Out:
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)

# %%
X_cat.columns
# Out:
# Index(['State', 'Coverage', 'Education', 'EmploymentStatus', 'Gender',
#        'Location Code', 'Marital Status', 'Policy Type', 'Policy',
#        'Renew Offer Type', 'Sales Channel', 'Vehicle Class', 'Vehicle Size'],
#       dtype='object')

# %%
ordinal_lst = ['Coverage', 'EmploymentStatus', 'Location Code', 'Vehicle Size', 'Education']

# %%
X_cat['Coverage'] = X_cat['Coverage'].map({'Basic' : 0, 'Extended' : 1, 'Premium' : 2})

# %%
X_cat['Coverage'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
X_cat['EmploymentStatus'].unique()
# Out:
# array(['Employed', 'Unemployed', 'Medical Leave', 'Disabled', 'Retired'],
#       dtype=object)

# %%
X_cat['EmploymentStatus'] = X_cat['EmploymentStatus'].map({'Employed' : 0, 'Retired' : 1, 'Disabled' : 2, 'Medical Leave' : 3, 'Unemployed' : 4})

# %%
X_cat['EmploymentStatus'].unique()
# Out:
# array([0, 4, 3, 2, 1], dtype=int64)

# %%
X_cat['Location Code'].unique()
# Out:
# array(['Suburban', 'Rural', 'Urban'], dtype=object)

# %%
X_cat['Location Code'] = X_cat['Location Code'].map({'Urban' : 0, 'Suburban' : 1, 'Rural' : 2})

# %%
X_cat['Location Code'].unique()
# Out:
# array([1, 2, 0], dtype=int64)

# %%
X_cat['Vehicle Size'].unique()
# Out:
# array(['Medsize', 'Small', 'Large'], dtype=object)

# %%
X_cat['Vehicle Size'] = X_cat['Vehicle Size'].map({'Small' : 0, 'Medsize' : 1, 'Large' : 2})

# %%
X_cat['Vehicle Size'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
X_cat['Education'].unique()
# Out:
# array(['College', 'High School or Below', 'Doctor'], dtype=object)

# %%
X_cat['Education'] = X_cat['Education'].map({'High School or Below' : 0, 'College' : 1, 'Doctor' : 2})

# %%
X_cat['Education'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
# encoded all ordinal values...
# now scale num and ordinal values:

# %%
X_num_ord = X_cat[ordinal_lst]

# %%
X_cat =  X_cat.drop(ordinal_lst, axis=1)

# %%
X_cat.columns
# Out:
# Index(['State', 'Gender', 'Marital Status', 'Policy Type', 'Policy',
#        'Renew Offer Type', 'Sales Channel', 'Vehicle Class'],
#       dtype='object')

# %%
#X_cat = X_cat.drop(['Gender'], axis = 1)

# %%
X_num_ord.head()
# Out:
#    Coverage  EmploymentStatus  Location Code  Vehicle Size  Education
# 0         0                 0              1             1          1
# 1         1                 4              1             1          1
# 2         2                 0              1             1          1
# 3         0                 4              1             1          1
# 4         0                 0              2             1          1

# %%
#X_num_ord = X_num_ord.drop('Education', axis=1)

# %%
X_num.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception
# 0                       32                              5
# 1                       13                             42
# 2                       18                             38
# 3                       18                             65
# 4                       12                             44

# %%
X_num = pd.concat([X_num,X_num_ord], axis = 1)

# %%
X_num.shape
# Out:
# (8651, 10)

# %%
transformer = StandardScaler().fit(X_num)
x_standardized = transformer.transform(X_num)

# %%
for i in range(x_standardized.shape[1]):
    sns.distplot(x_standardized[:,i])
    plt.show()

# %%
X_cat.shape
# Out:
# (8651, 8)

# %%
X_cat_encoded = pd.get_dummies(X_cat, drop_first=True)

# %%
X_cat_encoded.shape
# Out:
# (8651, 28)

# %%
x_standardized.shape
# Out:
# (8651, 10)

# %%
X_std = pd.DataFrame(x_standardized)

# %%
X_std.shape
# Out:
# (8651, 10)

# %%
X_Model = np.concatenate([X_std,X_cat_encoded],axis=1)

# %%
X_Model.shape
# Out:
# (8651, 38)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_Model, Y, test_size=0.3, random_state=100)

# %%
lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)
predictions  = lm.predict(X_test)
r2_score(y_test, predictions)
# Out:
# 0.5832281771399171

# %%
mse = mean_squared_error(y_test, predictions)
rmse = math.sqrt(mse)
print(mse)
print(rmse)
# Out:
# 26341.895305075217
# 162.30186476154614

# %%
# Still spaced for improvement...
