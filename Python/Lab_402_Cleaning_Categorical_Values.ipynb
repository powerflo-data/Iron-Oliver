# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns', None)
import math
import warnings
warnings.filterwarnings('ignore')
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from scipy import stats

# %%
# %run ../Iron_Oliver.ipynb

# %%
customer_df = pd.read_csv('Unit402_Lab.txt')

# %%
continuous_df = get_continous_cols_from_df(customer_df,10)
discrete_df = get_discrete_cols_from_df(customer_df,10)
cat_df = get_cat_cols_from_df(customer_df,10)

# %%
continuous_df.head()
# Out:
#    Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0              2763.519279   56274                    69
# 1              6979.535903       0                    94
# 2             12887.431650   48767                   108
# 3              7645.861827       0                   106
# 4              2813.692575   43836                    73
#
#    Months Since Last Claim  Months Since Policy Inception  Total Claim Amount
# 0                       32                              5          384.811147
# 1                       13                             42         1131.464935
# 2                       18                             38          566.472247
# 3                       18                             65          529.881344
# 4                       12                             44          138.130879

# %%
discrete_df.head()
# Out:
#    Number of Open Complaints  Number of Policies
# 0                          0                   1
# 1                          0                   8
# 2                          0                   2
# 3                          0                   7
# 4                          0                   1

# %%
correlations_matrix = continuous_df.corr()
mask = np.zeros_like(correlations_matrix)
mask[np.triu_indices_from(mask)] = True
fig, ax = plt.subplots(figsize=(15, 12))
ax = sns.heatmap(correlations_matrix, mask=mask, annot=True)
plt.show()

# %%
# Both in discrete and Cat_df, we could combine different features to fewer ones
plot_count_discrete_vals_from_df(discrete_df)

# %%
plot_count_discrete_vals_from_df(cat_df)

# %%
plot_bar_Ystring_discrete_vals_from_df(customer_df[['Total Claim Amount','Number of Open Complaints', 'Number of Policies']],'Total Claim Amount')

# %%
# What can you see in the plots?
# The counts of the specific values in the whole DF

# %%
#Plot Continous:       
plot_dist_continue_vals_from_df(continuous_df)

# %%
# Outliners:
plot_box_continue_vals_from_df(continuous_df)

# %%
# Total Claim Amount hast many outliners
iqr = np.percentile(model_data['Total Claim Amount'],75) - np.percentile(model_data['Total Claim Amount'],25)
upper_limit = np.percentile(model_data['Total Claim Amount'],75) + 1.5*iqr
lower_limit = np.percentile(model_data['Total Claim Amount'],25) - 1.5*iqr
#model_data = model_data[(model_data['Total Claim Amount']>lower_limit) & (model_data['Total Claim Amount']<upper_limit)]

# %%
#  Check for nans
customer_df.isnull().sum()/len(customer_df)
# Out:
# Customer                         0.0
# State                            0.0
# Customer Lifetime Value          0.0
# Response                         0.0
# Coverage                         0.0
# Education                        0.0
# Effective To Date                0.0
# EmploymentStatus                 0.0
# Gender                           0.0
# Income                           0.0
# Location Code                    0.0
# Marital Status                   0.0
# Monthly Premium Auto             0.0
# Months Since Last Claim          0.0
# Months Since Policy Inception    0.0
# Number of Open Complaints        0.0
# Number of Policies               0.0
# Policy Type                      0.0
# Policy                           0.0
# Renew Offer Type                 0.0
# Sales Channel                    0.0
# Total Claim Amount               0.0
# Vehicle Class                    0.0
# Vehicle Size                     0.0
# dtype: float64
